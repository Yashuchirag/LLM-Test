# %%
import pandas as pd

# %%
# !pip install langchain faiss-cpu sentence-transformers openai python-dotenv
# Out:
# Collecting langchain
#   Downloading langchain-0.3.24-py3-none-any.whl.metadata (7.8 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting openai
#   Downloading openai-1.76.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: python-dotenv in d:\software\python\lib\site-packages (0.21.0)
# Collecting langchain-core<1.0.0,>=0.3.55 (from langchain)
#   Downloading langchain_core-0.3.55-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.33-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\software\python\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in d:\software\python\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\software\python\lib\site-packages (from langchain) (6.0)
# Collecting numpy<3.0,>=1.25.0 (from faiss-cpu)
#   Downloading numpy-2.2.5-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging in d:\software\python\lib\site-packages (from faiss-cpu) (23.1)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: tqdm in d:\software\python\lib\site-packages (from sentence-transformers) (4.65.0)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.7.0-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: scikit-learn in d:\software\python\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in d:\software\python\lib\site-packages (from sentence-transformers) (1.11.1)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in d:\software\python\lib\site-packages (from sentence-transformers) (10.0.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\software\python\lib\site-packages (from sentence-transformers) (4.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\software\python\lib\site-packages (from openai) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\software\python\lib\site-packages (from openai) (0.26.0)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in d:\software\python\lib\site-packages (from openai) (1.2.0)
# Collecting typing_extensions>=4.5.0 (from sentence-transformers)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: idna>=2.8 in d:\software\python\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in d:\software\python\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in d:\software\python\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\software\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in d:\software\python\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.9.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\software\python\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (8.2.2)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.55->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging (from faiss-cpu)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.16-cp311-cp311-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\software\python\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.33.1-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\python\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\python\lib\site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: greenlet!=0.4.17 in d:\software\python\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in d:\software\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in d:\software\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in d:\software\python\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\software\python\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.7.9)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: joblib>=1.1.1 in d:\software\python\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\software\python\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Collecting numpy<3.0,>=1.25.0 (from faiss-cpu)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied
4 MB/s eta 0:00:06
#    ---------------------------------- ----- 181.9/212.5 MB 5.4 MB/s eta 0:00:06
#    ---------------------------------- ----- 182.7/212.5 MB 5.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 184.0/212.5 MB 5.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 185.3/212.5 MB 5.3 MB/s eta 0:00:06
#    ----------------------------------- ---- 186.9/212.5 MB 5.2 MB/s eta 0:00:05
#    ----------------------------------- ---- 188.0/212.5 MB 5.2 MB/s eta 0:00:05
#    ----------------------------------- ---- 189.3/212.5 MB 5.2 MB/s eta 0:00:05
#    ----------------------------------- ---- 190.6/212.5 MB 5.2 MB/s eta 0:00:05
#    ------------------------------------ --- 191.9/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------ --- 193.2/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------ --- 194.2/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------ --- 195.3/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------ --- 195.8/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------- -- 196.6/212.5 MB 5.2 MB/s eta 0:00:04
#    ------------------------------------- -- 197.4/212.5 MB 5.2 MB/s eta 0:00:03
#    ------------------------------------- -- 197.7/212.5 MB 5.2 MB/s eta 0:00:03
#    ------------------------------------- -- 198.4/212.5 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------- -- 199.5/212.5 MB 5.1 MB/s eta 0:00:03
#    ------------------------------------- -- 200.8/212.5 MB 5.1 MB/s eta 0:00:03
#    -------------------------------------- - 202.1/212.5 MB 5.1 MB/s eta 0:00:03
#    -------------------------------------- - 203.7/212.5 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 205.0/212.5 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 206.0/212.5 MB 5.1 MB/s eta 0:00:02
#    -------------------------------------- - 207.1/212.5 MB 5.1 MB/s eta 0:00:02
#    ---------------------------------------  208.1/212.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  209.2/212.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  210.2/212.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  211.8/212.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  212.3/212.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 212.5/212.5 MB 4.9 MB/s eta 0:00:00
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/10.4 MB 7.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.4 MB 8.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.0/10.4 MB 8.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.4 MB 8.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.4 MB 8.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.7/10.4 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 7.4 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/15.8 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/15.8 MB 4.6 MB/s eta 0:00:04
#    ------- -------------------------------- 3.1/15.8 MB 4.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.2/15.8 MB 5.0 MB/s eta 0:00:03
#    ------------- -------------------------- 5.2/15.8 MB 5.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.8/15.8 MB 5.4 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.8 MB 5.7 MB/s eta 0:00:02
#    ------------------------ --------------- 9.7/15.8 MB 5.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.3/15.8 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.8 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 5.8 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.16-cp311-cp311-win_amd64.whl (133 kB)
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 5.6 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.2 MB 6.4 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 6.9 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 6.1 MB/s eta 0:00:00
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------------------- -------------- 1.6/2.4 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 6.1 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading zstandard-0.23.0-cp311-cp311-win_amd64.whl (495 kB)
# Installing collected packages: zstandard, typing_extensions, sympy, safetensors, packaging, orjson, numpy, jsonpatch, jiter, fsspec, distro, annotated-types, typing-inspection, torch, pydantic-core, huggingface-hub, faiss-cpu, tokenizers, pydantic, transformers, openai, langsmith, sentence-transformers, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.19.0
#     Uninstalling zstandard-0.19.0:
#       Successfully uninstalled zstandard-0.19.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.11.1
#     Uninstalling sympy-1.11.1:
#       Successfully uninstalled sympy-1.11.1
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.3.2
#     Uninstalling safetensors-0.3.2:
#       Successfully uninstalled safetensors-0.3.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.15.1
#     Uninstalling huggingface-hub-0.15.1:
#       Successfully uninstalled huggingface-hub-0.15.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.8
#     Uninstalling pydantic-1.10.8:
#       Successfully uninstalled pydantic-1.10.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.32.1
#     Uninstalling transformers-4.32.1:
#       Successfully uninstalled transformers-4.32.1
# Successfully installed annotated-types-0.7.0 distro-1.9.0 faiss-cpu-1.10.0 fsspec-2025.3.2 huggingface-hub-0.30.2 jiter-0.9.0 jsonpatch-1.33 langchain-0.3.24 langchain-core-0.3.55 langchain-text-splitters-0.3.8 langsmith-0.3.33 numpy-1.26.4 openai-1.76.0 orjson-3.10.16 packaging-24.2 pydantic-2.11.3 pydantic-core-2.33.1 safetensors-0.5.3 sentence-transformers-4.1.0 sympy-1.13.3 tokenizers-0.21.1 torch-2.7.0 transformers-4.51.3 typing-inspection-0.4.0 typing_extensions-4.13.2 zstandard-0.23.0
# WARNING: Ignoring invalid distribution ~otebook (D:\Software\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (D:\Software\Python\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'D:\Software\Python\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~otebook (D:\Software\Python\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.11.3 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2025.3.2 which is incompatible.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in d:\software\python\lib\site-packages (24.3.1)
# Collecting pip
#   Using cached pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-25.0.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)

# %%
# !pip install update
# Out:
# Requirement already satisfied: update in d:\software\python\lib\site-packages (0.0.1)
# Requirement already satisfied: style==1.1.0 in d:\software\python\lib\site-packages (from update) (1.1.0)
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (d:\Software\Python\Lib\site-packages)

# %%
conda create -n rag-env python=3.10

# %%
import os
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.docstore.document import Document
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 import os
# ----> 2 from langchain.vectorstores import FAISS
#       3 from langchain.embeddings import HuggingFaceEmbeddings
#       4 from langchain.document_loaders import TextLoader
#
# File d:\Software\Python\Lib\site-packages\langchain\vectorstores\__init__.py:24
#       1 """**Vector store** stores embedded data and performs vector search.
#       2
#       3 One of the most common ways to store and search over unstructured data is to
#    (...)
#      19     Embeddings, Document
#      20 """  # noqa: E501
#      22 from typing import TYPE_CHECKING, Any
# ---> 24 from langchain_core.vectorstores import VectorStore
#      26 from langchain._api import create_importer
#      28 if TYPE_CHECKING:
#
# File d:\Software\Python\Lib\site-packages\langchain_core\vectorstores\__init__.py:28, in __getattr__(attr_name)
#      26 def __getattr__(attr_name: str) -> object:
#      27     module_name = _dynamic_imports.get(attr_name)
# ---> 28     result = import_attr(attr_name, module_name, __spec__.parent)
#      29     globals()[attr_name] = result
#      30     return result
#
# File d:\Software\Python\Lib\site-packages\langchain_core\_import_utils.py:29, in import_attr(attr_name, module_name, package)
#      27 else:
#      28     try:
# ---> 29         module = import_module(f".{module_name}", package=package)
#      30     except ModuleNotFoundError:
#      31         msg = f"module '{package!r}.{module_name!r}' not found"
#
# File d:\Software\Python\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\Software\Python\Lib\site-packages\langchain_core\vectorstores\base.py:38
#      28 from itertools import cycle
#      29 from typing import (
#      30     TYPE_CHECKING,
#      31     Any,
#    (...)
#      35     TypeVar,
#      36 )
# ---> 38 from pydantic import ConfigDict, Field, model_validator
#      39 from typing_extensions import Self, override
#      41 from langchain_core.embeddings import Embeddings
#
# File d:\Software\Python\Lib\site-packages\pydantic\__init__.py:413
#     242 _dynamic_imports: 'dict[str, tuple[str, str]]' = {
#     243     'dataclasses': (__spec__.parent, '__module__'),
#     244     # functional validators
#    (...)
#     409     'GenerateSchema': (__spec__.parent, '._internal._generate_schema'),
#     410 }
#     411 _deprecated_dynamic_imports = {'FieldValidationInfo', 'GenerateSchema'}
# --> 413 _getattr_migration = getattr_migration(__name__)
#     416 def __getattr__(attr_name: str) -> object:
#     417     if attr_name in _deprecated_dynamic_imports:
#
# File d:\Software\Python\Lib\site-packages\pydantic\_migration.py:260, in getattr_migration(module)
#     250 """Implement PEP 562 for objects that were either moved or removed on the migration
#     251 to V2.
#     252
#    (...)
#     257     A callable that will raise an error if the object is not found.
#     258 """
#     259 # This avoids circular import with errors.py.
# --> 260 from .errors import PydanticImportError
#     262 def wrapper(name: str) -> object:
#     263     """Raise an error if the object is not found, or warn if it was moved.
#     264
#     265     In case it was moved, it still returns the object.
#    (...)
#     271         The object.
#     272     """
#
# File d:\Software\Python\Lib\site-packages\pydantic\errors.py:9
#       6 from typing import Any, ClassVar, Literal
#       8 from typing_extensions import Self
# ----> 9 from typing_inspection.introspection import Qualifier
#      11 from pydantic._internal import _repr
#      13 from ._migration import getattr_migration
#
# File d:\Software\Python\Lib\site-packages\typing_inspection\introspection.py:14
#      10 from typing import Any, Literal, NamedTuple, cast
#      12 from typing_extensions import TypeAlias, assert_never, get_args, get_origin
# ---> 14 from . import typing_objects
#      16 __all__ = (
#      17     'AnnotationSource',
#      18     'ForbiddenQualifier',
#    (...)
#      23     'is_union_origin',
#      24 )
#      26 if sys.version_info >= (3, 10):
#
# File d:\Software\Python\Lib\site-packages\typing_inspection\typing_objects.py:19
#      16 from typing import Any, Final
#      18 import typing_extensions
# ---> 19 from typing_extensions import LiteralString, TypeAliasType, TypeIs, deprecated
#      21 __all__ = (
#      22     'DEPRECATED_ALIASES',
#      23     'NoneType',
#    (...)
#      52     'is_unpack',
#      53 )
#      55 _IS_PY310 = sys.version_info[:2] == (3, 10)
#
# ImportError: cannot import name 'TypeIs' from 'typing_extensions' (d:\Software\Python\Lib\site-packages\typing_extensions.py)
