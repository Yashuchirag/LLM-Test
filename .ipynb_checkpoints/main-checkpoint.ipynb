# %%
from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np
from langchain.vectorstores import FAISS
from langchain.llms import Ollama
from langchain.embeddings import OllamaEmbeddings
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import TextLoader
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import CharacterTextSplitter
from langchain.docstore.document import Document


load_dotenv()
# Out:
# True

# %%
# Load & chunk the Sikka API docs
df = pd.read_csv("Sikka_APIs - Sikka_APIs.csv", encoding="utf-8")

# %%
df.describe()
# Out:
#             API Name                              Description  \
# count             93                                       93
# unique            93                                       89
# top     appointments  Returns appointments data from practice
# freq               1                                        2
#
#                                     API Endpoints  \
# count                                          93
# unique                                         93
# top     https://api.sikkasoft.com/v4/appointments
# freq                                            1
#
#                                             Document Link
# count                                                  93
# unique                                                 92
# top     https://apidocs.sikkasoft.com/#9086881d-f5cc-4...
# freq                                                    2

# %%
df.head(5)
# Out:
#                            API Name  \
# 0                      appointments
# 1      appointments_available_slots
# 2              accounts_receivables
# 3  accounts_receivables_by_patients
# 4                          patients
#
#                                          Description  \
# 0            Returns appointments data from practice
# 1  Returns available appointments slots from prac...
# 2  Returns account receivables details from practice
# 3  Returns account receivables details by patient...
# 4               Returns list of patients in practice
#
#                                        API Endpoints  \
# 0          https://api.sikkasoft.com/v4/appointments
# 1  https://api.sikkasoft.com/v4/appointments_avai...
# 2  https://api.sikkasoft.com/v4/accounts_receivables
# 3  https://api.sikkasoft.com/v4/accounts_receivab...
# 4              https://api.sikkasoft.com/v4/patients
#
#                                        Document Link
# 0  https://apidocs.sikkasoft.com/#cc4375ec-0b6a-4...
# 1  https://apidocs.sikkasoft.com/#6b18ec4a-cfec-4...
# 2  https://apidocs.sikkasoft.com/#fcb005b7-b9ce-4...
# 3  https://apidocs.sikkasoft.com/#3ae94fe1-4b24-4...
# 4  https://apidocs.sikkasoft.com/#67aa35de-a4d4-4...

# %%
# Combine data into a single string

docs = []
for i, row in df.iterrows():
    content = f"API Name: {row['API Name']}\nDescription: {row['Description']}\nEndpoint: {row['API Endpoints']}\nDoc Link: {row['Document Link']}"
    docs.append(Document(page_content=content))

# %%
len(docs)
# Out:
# 93

# %%
# Creating vector store with FAISS

embeddings = OllamaEmbeddings(model="mistral")
vectorstore = FAISS.from_documents(docs, embeddings)
retriever = vectorstore.as_retriever()
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_33040\3665739574.py:3: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="mistral")

# %%
# Initialize language model

llm = Ollama(model="mistral")
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_33040\2761387838.py:3: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="mistral")

# %%
# RAG QA chain
retrieval_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    chain_type="stuff"
)

# %%
# Step 11: Ask a Question Using the Retriever
query = "List all API names?"
response = retrieval_chain.run(query)

# Step 12: Print the Result
print("\nQuery:", query)
print("\nResponse:", response)
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_33040\305958217.py:3: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = retrieval_chain.run(query)
# Query: List all API names?
#
# Response: 1. vendors
# 2. shelter_patients
# 3. fee_schedules
# 4. authorized_practices

# %%
query = "Which API endpoint can be used to retrieve patient payment details?"
response = retrieval_chain.run(query)

# Step 10: Output Result
print("\nQuery:", query)
print("\nResponse:", response)
# Out:
# Query: Which API endpoint can be used to retrieve patient payment details?
#
# Response:  I'm sorry for any inconvenience, but the provided context does not contain an API that retrieves patient payment details. If you have more information or a different perspective, I would be happy to help further!

# %%
docs[1]
# Out:
# Document(metadata={}, page_content='API Name: appointments_available_slots\nDescription: Returns available appointments slots from practice.\nEndpoint: https://api.sikkasoft.com/v4/appointments_available_slots\nDoc Link: https://apidocs.sikkasoft.com/#6b18ec4a-cfec-4a69-976d-678d2bfb0fe4')

# %%
query = "Get patient payments"
response = retrieval_chain.run(query)

# Step 10: Output Result
print("\nQuery:", query)
print("\nResponse:", response)
# Out:
# Query: Get patient payments
#
# Response:  To get patient payments data, it's not explicitly mentioned in the provided context. However, if we assume that payment information is related to either patient_documents or patient_contracts, I would suggest using the patient_contracts API as it returns contract data from the practice, and contracts might include payment details.
#
# If my assumption is correct, you can use the following information:
# API Name: patient_contracts
# Description: Returns patient contract data from practice
# Endpoint: https://api.sikkasoft.com/v4/patient_contracts
# Doc Link: https://apidocs.sikkasoft.com/#3a18d76f-5a50-4a4f-b7c8-30c837e19eea
